# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading data

# %%
df = pd.read_csv('new_winequality_red.csv')
df
# Out:
#       fixed_acidity volatile_acidity citric_acid  residual_sugar  chlorides  \
# 0               7.4           medium         low             1.9      0.076
# 1               7.8             high         low             2.6      0.098
# 2               7.8           medium         low             2.3      0.092
# 3              11.2              low        high             1.9      0.075
# 4               7.4           medium         low             1.9      0.076
# ...             ...              ...         ...             ...        ...
# 1594            6.2           medium         low             2.0      0.090
# 1595            5.9           medium         low             2.2      0.062
# 1596            6.3           medium         low             2.3      0.076
# 1597            5.9           medium         low             2.0      0.075
# 1598            6.0              low      medium             3.6      0.067
#
# ...

# %% [markdown]
# # 2. Kokybės analizė

# %%
df.describe()
# Out:
#        fixed_acidity  residual_sugar    chlorides  free_sulfur_dioxide  \
# count    1599.000000     1599.000000  1599.000000          1599.000000
# mean        8.319637        2.538806     0.087467            15.874922
# std         1.741096        1.409928     0.047065            10.460157
# min         4.600000        0.900000     0.012000             1.000000
# 25%         7.100000        1.900000     0.070000             7.000000
# 50%         7.900000        2.200000     0.079000            14.000000
# 75%         9.200000        2.600000     0.090000            21.000000
# max        15.900000       15.500000     0.611000            72.000000
#
#        total_sulfur_dioxide      density           pH    sulphates  \
# count           1599.000000  1599.000000  1599.000000  1599.000000
# mean              46.467792     0.996747     3.311113     0.658149
# std               32.895324     0.001887     0.154386     0.169507
# ...

# %% [markdown]
# * Kardinalumas

# %%
df.nunique()
# Out:
# fixed_acidity            96
# volatile_acidity          3
# citric_acid               4
# residual_sugar           91
# chlorides               153
# free_sulfur_dioxide      60
# total_sulfur_dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                   7
# quality                   6
# dtype: int64

# %%
df_mode = df.mode()
df_mode
# Out:
#    fixed_acidity volatile_acidity citric_acid  residual_sugar  chlorides  \
# 0            7.2           medium         low             2.0       0.08
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density   pH  sulphates  \
# 0                  6.0                  28.0   0.9972  3.3        0.6
#
#       alcohol  quality
# 0  medium low        5

# %%
df_median = df.median(numeric_only=None)
df_median
# Out:
# C:\Users\Justis\AppData\Local\Temp\ipykernel_12620\3051607173.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_median = df.median(numeric_only=None)
# fixed_acidity            7.90000
# residual_sugar           2.20000
# chlorides                0.07900
# free_sulfur_dioxide     14.00000
# total_sulfur_dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# quality                  6.00000
# dtype: float64

# %%
df['volatile_acidity'].value_counts()
# Out:
# medium    1050
# low        445
# high       104
# Name: volatile_acidity, dtype: int64

# %%
df['citric_acid'].value_counts()
# Out:
# low          794
# medium       615
# high         184
# very high      6
# Name: citric_acid, dtype: int64

# %%
df['alcohol'].value_counts()
# Out:
# medium low     710
# medium         444
# medium high    267
# high           118
# low             37
# very high       22
# extra high       1
# Name: alcohol, dtype: int64

# %% [markdown]
# # 4. Atributų histogramos

# %%
df.fixed_acidity.plot(kind='hist',title='fixed acidity')
# Out:
# <AxesSubplot:title={'center':'fixed acidity'}, ylabel='Frequency'>

# %%
df.volatile_acidity.value_counts().plot(kind='bar',title='volatile acidity')
# Out:
# <AxesSubplot:title={'center':'volatile acidity'}>

# %%
df.citric_acid.value_counts().plot(kind='bar',title='citric acid')
# Out:
# <AxesSubplot:title={'center':'citric acid'}>

# %%
df.residual_sugar.plot(kind='hist',title='residual sugar')
# Out:
# <AxesSubplot:title={'center':'residual sugar'}, ylabel='Frequency'>

# %%
df.chlorides.plot(kind='hist',title='chlorides')
# Out:
# <AxesSubplot:title={'center':'chlorides'}, ylabel='Frequency'>

# %%
df.free_sulfur_dioxide.plot(kind='hist',title='free sulfur dioxide')
# Out:
# <AxesSubplot:title={'center':'free sulfur dioxide'}, ylabel='Frequency'>

# %%
df.total_sulfur_dioxide.plot(kind='hist',title='total sulfur dioxide')
# Out:
# <AxesSubplot:title={'center':'total sulfur dioxide'}, ylabel='Frequency'>

# %%
df.density.plot(kind='hist',title='density')
# Out:
# <AxesSubplot:title={'center':'density'}, ylabel='Frequency'>

# %%
df.pH.plot(kind='hist',title='pH')
# Out:
# <AxesSubplot:title={'center':'pH'}, ylabel='Frequency'>

# %%
df.sulphates.plot(kind='hist',title='sulphates')
# Out:
# <AxesSubplot:title={'center':'sulphates'}, ylabel='Frequency'>

# %%
df.alcohol.value_counts().plot(kind='bar',title='alcohol')
# Out:
# <AxesSubplot:title={'center':'alcohol'}>

# %%
df.quality.plot(kind='hist',title='quality')
# Out:
# <AxesSubplot:title={'center':'quality'}, ylabel='Frequency'>

# %% [markdown]
# # 7. Sąryšių vizualicija

# %% [markdown]
# * Scatter plot

# %%
df.plot.scatter(x='total_sulfur_dioxide', y='free_sulfur_dioxide', c='DarkBlue', s=0.5)
# Out:
# <AxesSubplot:xlabel='total_sulfur_dioxide', ylabel='free_sulfur_dioxide'>

# %%
df.plot.scatter(x='fixed_acidity', y='pH', c='DarkBlue', s=0.5)
# Out:
# <AxesSubplot:xlabel='fixed_acidity', ylabel='pH'>

# %%
df.plot.scatter(x='density', y='sulphates', c='DarkBlue', s=0.5)
# Out:
# <AxesSubplot:xlabel='density', ylabel='sulphates'>

# %%
df.plot.scatter(x='density', y='fixed_acidity', c='DarkBlue', s=0.5)
# Out:
# <AxesSubplot:xlabel='density', ylabel='fixed_acidity'>

# %%
df.plot.scatter(x='sulphates', y='quality', c='DarkBlue', s=0.5)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %% [markdown]
# * Kategoriniai

# %% [markdown]
# * Bar plot

# %%
df[['alcohol','quality']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='alcohol,quality'>

# %%
df[['alcohol','volatile_acidity']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='alcohol,volatile_acidity'>

# %%
df[['volatile_acidity','citric_acid']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='volatile_acidity,citric_acid'>

# %% [markdown]
# * SPLOM

# %%
sns.pairplot(df,height=10)

# %% [markdown]
# * Koreliacijos matrica

# %%
plt.figure(figsize=(20, 10))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Koreliacijos matrica', fontdict={'fontsize':30}, pad=12);

# %% [markdown]
# * Box plot

# %%
sns.boxplot(data=df, x="citric_acid", y="density")
# Out:
# <AxesSubplot:xlabel='citric_acid', ylabel='density'>

# %%
sns.boxplot(data=df, x="volatile_acidity", y="fixed_acidity")
# Out:
# <AxesSubplot:xlabel='volatile_acidity', ylabel='fixed_acidity'>

# %%
df["alcohol"]=df["alcohol"].astype('category').cat.codes
df
# Out:
#       fixed_acidity volatile_acidity citric_acid  residual_sugar  chlorides  \
# 0               7.4           medium         low             1.9      0.076
# 1               7.8             high         low             2.6      0.098
# 2               7.8           medium         low             2.3      0.092
# 3              11.2              low        high             1.9      0.075
# 4               7.4           medium         low             1.9      0.076
# ...             ...              ...         ...             ...        ...
# 1594            6.2           medium         low             2.0      0.090
# 1595            5.9           medium         low             2.2      0.062
# 1596            6.3           medium         low             2.3      0.076
# 1597            5.9           medium         low             2.0      0.075
# 1598            6.0              low      medium             3.6      0.067
#
# ...
